# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open("train_imagenet.log") as f:
    data = f.read()

# %%
# 'top1', 74.5520000415039

top1 = [float(num) for num in re.findall(r"top1', (\d+\.\d+)", data)][:88]

# %%
df = pd.DataFrame(top1, columns=["top1"])
df.plot()
# Out:
# <Axes: >
